# %%
import numpy as np

# %%
data=np.array([[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[23]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]])

# %%
data.ndim
# Out:
# 32

# %%
data1=np.array([[[2,3,1,4],[3,2,1,2]],[[3,3,27,2],[2,4,2,1]],[[2,32,32,17],[4,12,14,24]],[[2,32,32,17],[4,12,14,24]]])

# %%
data1.ndim
# Out:
# 3

# %%
a=data1.reshape(4,8)

# %%
a
# Out:
# array([[ 2,  3,  1,  4,  3,  2,  1,  2],
#        [ 3,  3, 27,  2,  2,  4,  2,  1],
#        [ 2, 32, 32, 17,  4, 12, 14, 24],
#        [ 2, 32, 32, 17,  4, 12, 14, 24]])

# %%
data=np.array([a])

# %%
data
# Out:
# array([[[ 2,  3,  1,  4,  3,  2,  1,  2],
#         [ 3,  3, 27,  2,  2,  4,  2,  1],
#         [ 2, 32, 32, 17,  4, 12, 14, 24],
#         [ 2, 32, 32, 17,  4, 12, 14, 24]]])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("sign_mnist_train.csv")

# %%
data
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27450     13     189     189     190     190     192     193     193     193
# 27451     23     151     154     157     158     160     161     163     164
# 27452     18     174     174     174     174     174     175     175     174
# 27453     17     177     181     184     185     187     189     190     191
# 27454     23     179     180     180     180     182     181     182     183
#
# ...

# %%
y_train=data.iloc[:,0:1]

# %%
y_train.head(1)
# Out:
#    label
# 0      3

# %%
x_train=data.iloc[:,1:]

# %%
x_train
# Out:
#        pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0         107     118     127     134     139     143     146     150     153
# 1         155     157     156     156     156     157     156     158     158
# 2         187     188     188     187     187     186     187     188     187
# 3         211     211     212     212     211     210     211     210     210
# 4         164     167     170     172     176     179     180     184     185
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27450     189     189     190     190     192     193     193     193     193
# 27451     151     154     157     158     160     161     163     164     166
# 27452     174     174     174     174     174     175     175     174     173
# 27453     177     181     184     185     187     189     190     191     191
# 27454     179     180     180     180     182     181     182     183     182
#
# ...

# %%
data1=pd.read_csv("sign_mnist_test.csv")

# %%
y_test=data1.iloc[:,0:1]

# %%
y_test.head(1)
# Out:
#    label
# 0      6

# %%
x_test=data1.iloc[:,1:]

# %%
x_test.head(1)
# Out:
#    pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0     149     149     150     150     150     151     151     150     151
#
#    pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0      152  ...       138       148       127        89        82        96
#
#    pixel781  pixel782  pixel783  pixel784
# 0       106       112       120       107
#
# [1 rows x 784 columns]

# %%
# from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
obj=LogisticRegression()

# %%
obj.fit(x_train,y_train)
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# zx=np.array(x_test.values)

# %%
# zx.reshape(-1,1)

# %%
# obj.predict(zx)

# %%
a=x_test.iloc[6]

# %%
zx=np.array(a)

# %%
zx
# Out:
# array([ 93, 100, 112, 118, 123, 127, 131, 133, 136, 139, 140, 143, 144,
#        145, 146, 149, 151, 153, 154, 155, 156, 159, 159, 160, 160, 161,
#        163, 164,  93, 102, 113, 119, 123, 128, 131, 134, 138, 140, 141,
#        144, 145, 146, 148, 150, 137, 149, 155, 156, 158, 160, 160, 161,
#        162, 163, 164, 165,  95, 104, 114, 120, 124, 129, 132, 134, 139,
#        141, 142, 144, 147, 149, 153, 158, 119, 135, 157, 157, 159, 161,
#        162, 163, 164, 165, 165, 165,  98, 107, 117, 122, 126, 130, 133,
#        136, 139, 141, 143, 145, 148, 150, 158, 164, 122, 120, 157, 158,
#        161, 162, 163, 164, 165, 166, 167, 167,  99, 107, 117, 123, 127,
#        130, 134, 138, 140, 143, 144, 147, 149, 151, 158, 165, 130, 112,
#        156, 159, 162, 164, 164, 165, 167, 168, 168, 169,  99, 109, 119,
#        124, 127, 132, 136, 138, 140, 143, 145, 147, 149, 152, 155, 167,
#        140, 111, 153, 161, 163, 165, 166, 166, 168, 169, 169, 170, 100,
# ...

# %%
obj.predict([zx])
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([10], dtype=int64)

# %%
x=x_train.values.tolist()

# %%
plt.imshow(np.reshape(x[8],(28,28,1)))

# %%
import pandas as pd

# %%
x_test.head(1)
# Out:
#    pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0     149     149     150     150     150     151     151     150     151
#
#    pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0      152  ...       138       148       127        89        82        96
#
#    pixel781  pixel782  pixel783  pixel784
# 0       106       112       120       107
#
# [1 rows x 784 columns]

# %%
y_test.head()
# Out:
#    label
# 0      6
# 1      5
# 2     10
# 3      0
# 4      3

# %%
import joblib

# %%
joblib.dump(obj,"check_image.joblib")
# Out:
# ['check_image.joblib']
