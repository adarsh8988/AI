# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Dell\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([10,24,34,67])
y=np.array([100,400,500,677])

# %%
plt.plot(x,y,marker="o",ms=10,mfc="black",mec="gold",color="yellow",linewidth="5",linestyle="dashed")

# %%
plt.scatter(x,y,marker="o",s=100,c="black",edgecolors="gold",linewidths=5)
plt.grid()
plt.plot(xyz, abc, marker = "o", ms = 20, mfc = "red", mec = "black", color = "green", linewidth = 5, linestyle = "
