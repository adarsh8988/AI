# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr=np.array([12,34,54,43,30])
arr1=np.array(["a","b","c","d","e"])
plt.plot(arr,arr1)

# %%
plt.bar(arr,arr1,width=0.9)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(arr,arr1)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(arr)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f4928a5010>,
# ...
#  [Text(1.0739856231309737, 0.23781270215859907, ''),
#   Text(0.5442235673641062, 0.9559396993144946, ''),
#   Text(-0.9704074893444766, 0.5179858150800556, ''),
#   Text(-0.32468511818456436, -1.0509898068152115, ''),
#   Text(0.9407626946079919, -0.5700574992348671, '')])

# %%
x=np.array([20,30,40,10])
y=["orange","grapes","apple","banana"]

# %%
plt.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f492bf5010>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'orange'),
#   Text(-0.64656382751384, 0.8899186574910392, 'grapes'),
#   Text(-0.3399185762739153, -1.046162206115244, 'apple'),
#   Text(1.0461622140716127, -0.3399185517867209, 'banana')])

# %%
z=[0,0,0.1,0]

# %%
plt.pie(x,labels=y,explode=z,shadow=True,frame=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f492cce3d0>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'orange'),
#   Text(-0.64656382751384, 0.8899186574910392, 'grapes'),
#   Text(-0.37082026502608945, -1.1412678612166298, 'apple'),
#   Text(1.0461622140716127, -0.3399185517867209, 'banana')])

# %%
import pandas as pd

# %%
data=pd.read_csv("zim_test.csv")

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
x=data["Duration"]

# %%
x
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
#        ..
# 164    60
# 165    60
# 166    60
# 167    75
# 168    75
# Name: Duration, Length: 169, dtype: int64

# %%
y=data["Pulse"]
z=data["Maxpulse"]

# %%
z
# Out:
# 0      130
# 1      145
# 2      135
# 3      175
# 4      148
#       ...
# 164    140
# 165    145
# 166    145
# 167    150
# 168    150
# Name: Maxpulse, Length: 169, dtype: int64

# %%
plt.plot(x)
plt.plot(y)
plt.plot(z)
plt.xlabel("Duration")
plt.ylabel("Pulse")
plt.title("graph")
plt.grid()

# %%
plt.scatter
