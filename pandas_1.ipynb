# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Dell\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# ...

# %%
# Pandas
1. Series
2. Dataframe
3. iloc
4. index
5. read_csv
6. isnull
7. info
8. head
9. tail
10. mean
11. dropna
12. fillna
13. duplicates

# %%
import pandas as pd

# %% [markdown]
# # series

# %%
lst = [12, 10, 90, 67, 10, 45, 34, 100]

# %%
tst = pd.Series(lst)

# %%
tst
# Out:
# 0     12
# 1     10
# 2     90
# 3     67
# 4     10
# 5     45
# 6     34
# 7    100
# dtype: int64

# %%
data = {
    "Username" : ["kriss", "moris", "hlo", "uname", "gni"],
    "Age" : [12, 34, 23, 12, 45],
    "Number" : [92342234, 45645345, 234234234, 456546445, 67876856756]
}

# %%
type(data)
# Out:
# dict

# %% [markdown]
# # DataFrame

# %%
abc=pd.DataFrame(data)

# %%
abc
# Out:
#   Username  Age       Number
# 0    kriss   12     92342234
# 1    moris   34     45645345
# 2      hlo   23    234234234
# 3    uname   12    456546445
# 4      gni   45  67876856756

# %% [markdown]
# # iloc

# %%
abc.iloc[0]
# Out:
# Username       kriss
# Age               12
# Number      92342234
# Name: 0, dtype: object

# %%
abc.iloc[2]
# Out:
# Username          hlo
# Age                23
# Number      234234234
# Name: 2, dtype: object

# %% [markdown]
# # index

# %%
lst=[12,322,32,35,67,87,77]

# %%
xyz=pd.Series(lst,index=['a','b','c','d','e','f','g'])

# %%
xyz
# Out:
# a     12
# b    322
# c     32
# d     35
# e     67
# f     87
# g     77
# dtype: int64

# %% [markdown]
# # read_csv

# %%
dat= pd.read_csv("C:\\Users\\Dell//Downloads//Job_Placement_Data (1).csv")

# %%
dat
# Out:
#     gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0        M           67.00    Others           91.00    Others    Commerce
# 1        M           79.33   Central           78.33    Others     Science
# 2        M           65.00   Central           68.00   Central        Arts
# 3        M           56.00   Central           52.00   Central     Science
# 4        M           85.80   Central           73.60   Central    Commerce
# ..     ...             ...       ...             ...       ...         ...
# 210      M           80.60    Others           82.00    Others    Commerce
# 211      M           58.00    Others           60.00    Others     Science
# 212      M           67.00    Others           67.00    Others    Commerce
# 213      F           74.00    Others           66.00    Others    Commerce
# 214      M           62.00   Central           58.00    Others     Science
#
# ...

# %%
import pandas as pd

# %%
asbc=pd.read_csv("zim_test.csv")

# %%
asbc
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
asbc[asbc.isnull().any(axis=1)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %% [markdown]
# # info

# %%
asbc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
asbc.fillna(2000)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
asbc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
asbc.dropna()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
asbc.fillna(100,inplace=True)

# %%
asbc
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
asbc.head(30)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112     100.0
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# ...

# %% [markdown]
# # head, tail

# %%
asbc.head(25)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# ...

# %%
asbc=pd.read_csv("zim_test.csv")

# %%
asbc
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# # mean

# %%
x=asbc["Calories"].mean()

# %%
x
# Out:
# 375.79024390243904

# %%
asbc["Calories"].fillna(x,inplace=True)

# %%
asbc.head(25)
# Out:
#     Duration  Pulse  Maxpulse    Calories
# 0         60    110       130  409.100000
# 1         60    117       145  479.000000
# 2         60    103       135  340.000000
# 3         45    109       175  282.400000
# 4         45    117       148  406.000000
# 5         60    102       127  300.000000
# 6         60    110       136  374.000000
# 7         45    104       134  253.300000
# 8         30    109       133  195.100000
# 9         60     98       124  269.000000
# 10        60    103       147  329.300000
# 11        60    100       120  250.700000
# 12        60    106       128  345.300000
# 13        60    104       132  379.300000
# 14        60     98       123  275.000000
# 15        60     98       120  215.200000
# 16        60    100       120  300.000000
# 17        45     90       112  375.790244
# 18        60    103       123  323.000000
# 19        45     97       125  243.000000
# 20        60    108       131  364.200000
# ...

# %% [markdown]
# # wrong data

# %%
for i in asbc.index:
   if asbc.loc[i,"Duration"]>100:
    asbc.loc[i,"Duration"]=100

# %%
asbc.tail(60)
# Out:
#      Duration  Pulse  Maxpulse     Calories
# 109       100    137       184  1860.400000
# 110        60    102       124   325.200000
# 111        45    107       124   275.000000
# 112        15    124       139   124.200000
# 113        45    100       120   225.300000
# 114        60    108       131   367.600000
# 115        60    108       151   351.700000
# 116        60    116       141   443.000000
# 117        60     97       122   277.400000
# 118        60    105       125   375.790244
# 119        60    103       124   332.700000
# 120        30    112       137   193.900000
# 121        45    100       120   100.700000
# 122        60    119       169   336.700000
# 123        60    107       127   344.900000
# 124        60    111       151   368.500000
# 125        60     98       122   271.000000
# 126        60     97       124   275.300000
# 127        60    109       127   382.000000
# 128        90     99       125   466.400000
# ...

# %% [markdown]
# # duplicates

# %%
asbc.duplicated()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 asbc.duplicated(20)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6698, in DataFrame.duplicated(self, subset, keep)
#    6696 diff = set(subset) - set(self.columns)
#    6697 if diff:
# -> 6698     raise KeyError(Index(diff))
#    6700 if len(subset) == 1 and self.columns.is_unique:
#    6701     # GH#45236 This is faster than get_group_index below
#    6702     result = self[subset[0]].duplicated(keep)
#
# KeyError: Index([20], dtype='int64')

# %%
asbc.drop_duplicates()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [162 rows x 4 columns]

# %%
asbc[asbc.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Duration, Pulse, Maxpulse, Calories]
# Index: []
